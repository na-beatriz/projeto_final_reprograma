# %% [markdown]
# # Coleta dos Dados

# %%
#importando da biblioteca
import pandas as pd
import os
from glob import glob

# %% [markdown]
# # Limpeza e Tratamento dos datasets

# %%
#Base de óbitos maternos - Brasil por Cusa Obstetrica e Estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/causa_obstetrica/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado','Morte materna obst�trica direta':'Morte materna obstétrica direta','Morte materna obst�trica indireta':'Morte materna obstétrica indireta','Morte materna obst�trica n�o especificada':'Morte materna obstétrica não especificada'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_base_causa_obstetrica = arq_data
        inicio = False
    else:
        df_base_causa_obstetrica = pd.concat([df_base_causa_obstetrica, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_base_causa_obstetrica_2011_2021 = df_base_causa_obstetrica.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_base_causa_obstetrica_2011_2021['Estado'] = df_base_causa_obstetrica_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_base_causa_obstetrica_2011_2021 = df_base_causa_obstetrica_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Exportar para csv
df_base_causa_obstetrica_2011_2021.to_csv('./datasets/bases_tratadas/base_causa_obstetrica_2011_2021')

# %%
#Base de óbitos maternos - Brasil por Cor/Raça e Estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/cor_raca/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado','Ind�gena':'Indígena','Ignorado':'Cor/Raça Ignorado'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_base_cor_raca = arq_data
        inicio = False
    else:
        df_base_cor_raca = pd.concat([df_base_cor_raca, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_base_cor_raca_2011_2021 = df_base_cor_raca.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_base_cor_raca_2011_2021['Estado'] = df_base_cor_raca_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_base_cor_raca_2011_2021 = df_base_cor_raca_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Exportar para csv
df_base_cor_raca_2011_2021.to_csv('./datasets/bases_tratadas/base_cor_raca_2011_2021')

# %%
#Base de óbitos maternos - Brasil por Estado Civil e Estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/estado_civil/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado','Vi�vo':'Viúvo','Ignorado':'Estado Civil Ignorado'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_base_estado_civil = arq_data
        inicio = False
    else:
        df_base_estado_civil = pd.concat([df_base_estado_civil, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_base_estado_civil_2011_2021 = df_base_estado_civil.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_base_estado_civil_2011_2021['Estado'] = df_base_estado_civil_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_base_estado_civil_2011_2021 = df_base_estado_civil_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Exportar para csv
df_base_estado_civil_2011_2021.to_csv('./datasets/bases_tratadas/base_estado_civil_2011_2021')

# %%
#Base de óbitos maternos - Brasil por faixa-etária e Estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/faixa_etaria/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_base_faixa_etaria = arq_data
        inicio = False
    else:
        df_base_faixa_etaria = pd.concat([df_base_faixa_etaria, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_base_faixa_etaria_2011_2021 = df_base_faixa_etaria.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_base_faixa_etaria_2011_2021['Estado'] = df_base_faixa_etaria_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_base_faixa_etaria_2011_2021 = df_base_faixa_etaria_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Apagar coluna de 'Idade Ignorada'
df_base_faixa_etaria_2011_2021 = df_base_faixa_etaria_2011_2021.drop('Idade ignorada', axis=1)
#Exportar para csv
df_base_faixa_etaria_2011_2021.to_csv('./datasets/bases_tratadas/base_faixa_etaria_2011_2021')

# %%
#Base de óbitos maternos - Brasil por morte grav/puerp e Estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/morte_grav_puerp/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado','Durante o puerp�rio, at� 42 dias':'Durante o puerpério, até 42 dias','Durante o puerp�rio, de 43 dias a menos de 1 ano':'Durante o puerpério, de 43 dias a menos de 1 ano','N�o na gravidez ou no puerp�rio':'Não na gravidez ou no puerpério','Per�odo informado inconsistente':'Período informado inconsistente','N�o informado ou ignorado':'Não informado ou ignorado'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_base_morte_gravpuerp = arq_data
        inicio = False
    else:
        df_base_morte_gravpuerp = pd.concat([df_base_morte_gravpuerp, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_base_morte_gravpuerp_2011_2021 = df_base_morte_gravpuerp.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_base_morte_gravpuerp_2011_2021['Estado'] = df_base_morte_gravpuerp_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_base_morte_gravpuerp_2011_2021 = df_base_morte_gravpuerp_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Exportar para csv
df_base_morte_gravpuerp_2011_2021.to_csv('./datasets/bases_tratadas/base_morte_gravpuerp_2011_2021')

# %%
#Base de óbitos maternos - Brasil por ano/mês do óbito e estado
#Período:2011-2021
#Tratamento da base
arquivos = sorted(glob(r'./datasets/obito_mensal/*.csv'))
#Fazer coluna de ano em cada dataset
ano = 2011
inicio = True
for i in arquivos:
    arq_data = pd.read_csv(i, sep=';', encoding='utf-8')
    arq_data.rename(columns={'Unidade da Federa��o':'Estado','Mar�o':'Março'}, inplace = True)
    df_remove = arq_data.loc[(arq_data['Estado']  == "Total")]
    arq_data = arq_data.drop(df_remove.index)
    arq_data.insert(0,'ANO',allow_duplicates=True,value=ano)
    if inicio:
        df_obito_mensal = arq_data
        inicio = False
    else:
        df_obito_mensal = pd.concat([df_obito_mensal, arq_data],ignore_index=True)
    ano = ano + 1
#Apagar coluna de 'Total'
df_obito_mensal_2011_2021 = df_obito_mensal.drop('Total', axis=1)
#Apaga caracteres e espaçamento no início da coluna 'Estado'
df_obito_mensal_2011_2021['Estado'] = df_obito_mensal_2011_2021['Estado'].str.slice(3)
#Renomear nome dados da coluna 'Estado'
df_obito_mensal_2011_2021 = df_obito_mensal_2011_2021.replace(['Rond�nia','Par�','Amap�','Maranh�o','Piau�','Cear�','Para�ba','Esp�rito Santo','S�o Paulo','Paran�','Goi�s'],['Rondônia','Pará','Amapá','Maranhão','Piauí','Ceará','Paraíba','Espírito Santo','São Paulo','Paraná','Goiás'])
#Exportar para csv
df_obito_mensal_2011_2021.to_csv('./datasets/bases_finais/base_obito_mensal_2011_2021')

# %% [markdown]
# # Coleta dos dados
# Após o tratamento e limpeza dos datasets, para facilitar a leitura dos dataframes, estou expondo eles aqui

# %%
#Base causa obstetrica
df_base_causa_obstetrica_2011_2021
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
#Base cor/raça
df_base_cor_raca_2011_2021
# Out:
#       ANO              Estado Branca Preta Amarela Parda Indígena  \
# 0    2011            Rondônia      6     1       -     7        -
# 1    2011                Acre      3     -       -     2        1
# 2    2011            Amazonas      3     1       -    39        8
# 3    2011             Roraima      1     -       -     3        2
# 4    2011                Pará      9     9       -    67        -
# ..    ...                 ...    ...   ...     ...   ...      ...
# 292  2021   Rio Grande do Sul     88    11       -    13        1
# 293  2021  Mato Grosso do Sul     19     4       -    29        2
# 294  2021         Mato Grosso     29     6       1    45        3
# 295  2021               Goiás     50    16       -    71        -
# 296  2021    Distrito Federal     14     4       -    18        -
#
#     Cor/Raça Ignorado
# 0                   1
# 1                   -
# 2                   1
# 3                   -
# 4                   -
# ..                ...
# ...

# %%
#Base estado civil
df_base_estado_civil_2011_2021
# Out:
#       ANO              Estado  Solteiro Casado Viúvo Separado judicialmente  \
# 0    2011            Rondônia         6      5     -                      -
# 1    2011                Acre         3      -     -                      -
# 2    2011            Amazonas        30      9     1                      -
# 3    2011             Roraima         3      -     -                      -
# 4    2011                Pará        40     13     -                      -
# ..    ...                 ...       ...    ...   ...                    ...
# 292  2021   Rio Grande do Sul        54     29     -                      4
# 293  2021  Mato Grosso do Sul        31     15     -                      1
# 294  2021         Mato Grosso        40     29     -                      2
# 295  2021               Goiás        40     60     -                      6
# 296  2021    Distrito Federal        18     14     -                      1
#
#     Outro Estado Civil Ignorado
# ...

# %%
#Base faixa-etária
df_base_faixa_etaria_2011_2021
# Out:
#       ANO              Estado 10 a 14 anos 15 a 19 anos  20 a 29 anos  \
# 0    2011            Rondônia            -            1             9
# 1    2011                Acre            1            -             3
# 2    2011            Amazonas            -           17            14
# 3    2011             Roraima            -            2             1
# 4    2011                Pará            1           20            36
# ..    ...                 ...          ...          ...           ...
# 292  2021   Rio Grande do Sul            -            6            34
# 293  2021  Mato Grosso do Sul            -            7            21
# 294  2021         Mato Grosso            1            5            33
# 295  2021               Goiás            -            7            51
# 296  2021    Distrito Federal            -            4            11
#
#     30 a 39 anos 40 a 49 anos 50 a 59 anos
# 0              5            -            -
# ...

# %%
#Base morte grav/puerp
df_base_morte_gravpuerp_2011_2021
# Out:
#       ANO              Estado Durante a gravidez, parto ou aborto  \
# 0    2011            Rondônia                                   3
# 1    2011                Acre                                   1
# 2    2011            Amazonas                                  18
# 3    2011             Roraima                                   3
# 4    2011                Pará                                  29
# ..    ...                 ...                                 ...
# 292  2021   Rio Grande do Sul                                  27
# 293  2021  Mato Grosso do Sul                                  14
# 294  2021         Mato Grosso                                  26
# 295  2021               Goiás                                  39
# 296  2021    Distrito Federal                                   9
#
#     Durante o puerpério, até 42 dias  \
# 0                                  9
# 1                                  4
# 2                                 31
# ...

# %%
#Base óbito mensal
df_obito_mensal_2011_2021
# Out:
#       ANO              Estado Janeiro Fevereiro Março Abril Maio Junho Julho  \
# 0    2011            Rondônia       -         1     1     2    -     3     1
# 1    2011                Acre       1         2     -     -    2     -     -
# 2    2011            Amazonas       5         5     5     6    3     6     4
# 3    2011             Roraima       -         1     -     1    1     -     -
# 4    2011                Pará       7         5     5     5    7    10    12
# ..    ...                 ...     ...       ...   ...   ...  ...   ...   ...
# 292  2021   Rio Grande do Sul       6         2    20    17   12    14    10
# 293  2021  Mato Grosso do Sul       5         4    12     6    6     6     5
# 294  2021         Mato Grosso       7         2     9    20    7    18     6
# 295  2021               Goiás       5         9    25    24   15     9    14
# 296  2021    Distrito Federal       1         1     3     9    6     4     4
#
# ...

# %% [markdown]
# # Juntando Datasets

# %%
# Jutando os df causa obstetrica com cor/raça
df_morte_maternas = pd.merge(df_base_causa_obstetrica_2011_2021, df_base_cor_raca_2011_2021, on=['Estado', 'ANO'])
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
# Jutando os df mortes maternas com estado civil
df_morte_maternas = pd.merge(df_morte_maternas, df_base_estado_civil_2011_2021, on=['Estado', 'ANO'])
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
# Jutando os df mortes maternas com faixa-etária
df_morte_maternas = pd.merge(df_morte_maternas, df_base_faixa_etaria_2011_2021, on=['Estado', 'ANO'])
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
# Jutando os df mortes maternas com morte grav/puerp
df_morte_maternas = pd.merge(df_morte_maternas, df_base_morte_gravpuerp_2011_2021, on=['Estado', 'ANO'])
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
#Exportar para csv a base final mortes maternas
df_morte_maternas.to_csv('./datasets/bases_finais/base_mortes_maternas')

# %% [markdown]
# # Analisando os dados
#
# - Qual é o perfil dessa mulher?
#     - Cor/Raça;
#     - Faixa-Etária;
#     - Região;
#     - Estado civil;
#     - Período de falecimento
# - Ano que ocorreram mais falecimentos e em qual mês?
# - De acordo com o periódo que houvem mais falecimentos, quais foram os principais estados das ocorrências?

# %% [markdown]
# ### Análise do dataset Mortes Maternas

# %%
#Checando se a base final de morte maternas está boa
df_morte_maternas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297 entries, 0 to 296
# Data columns (total 29 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ANO                                               297 non-null    int64
#  1   Estado                                            297 non-null    object
#  2   Morte materna obstétrica direta                   297 non-null    int64
#  3   Morte materna obstétrica indireta                 297 non-null    object
#  4   Morte materna obstétrica não especificada         297 non-null    object
#  5   Branca                                            297 non-null    object
#  6   Preta                                             297 non-null    object
#  7   Amarela                                           297 non-null    object
#  8   Parda                                             297 non-null    object
# ...

# %%
#Verificando se há dados nulos em uma coluna específica
df_morte_maternas[df_morte_maternas['50 a 59 anos']. isnull ()]
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 54   2013            Rondônia                               12
# 55   2013                Acre                                7
# 56   2013            Amazonas                               36
# 57   2013             Roraima                                5
# 58   2013                Pará                               87
# ..    ...                 ...                              ...
# 211  2018   Rio Grande do Sul                               28
# 212  2018  Mato Grosso do Sul                               19
# 213  2018         Mato Grosso                               20
# 214  2018               Goiás                               48
# 215  2018    Distrito Federal                               19
#
#     Morte materna obstétrica indireta  \
# 54                                  6
# 55                                  3
# 56                                  8
# 57                                  1
# ...

# %%
#Renomear valor de dados da colunas
df_morte_maternas[['50 a 59 anos','Período informado inconsistente']] = df_morte_maternas[['50 a 59 anos','Período informado inconsistente']].fillna(0) 
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   -
# 2                                  18
# 3                                   2
# ...

# %%
#Renomear nome dados das colunas 
df_morte_maternas = df_morte_maternas.replace(['-'],[0])
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#     Morte materna obstétrica indireta  \
# 0                                   2
# 1                                   0
# 2                                  18
# 3                                   2
# ...

# %%
#Verificando informações gerais da base mortes maternas
df_morte_maternas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297 entries, 0 to 296
# Data columns (total 29 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ANO                                               297 non-null    int64
#  1   Estado                                            297 non-null    object
#  2   Morte materna obstétrica direta                   297 non-null    int64
#  3   Morte materna obstétrica indireta                 297 non-null    object
#  4   Morte materna obstétrica não especificada         297 non-null    object
#  5   Branca                                            297 non-null    object
#  6   Preta                                             297 non-null    object
#  7   Amarela                                           297 non-null    object
#  8   Parda                                             297 non-null    object
# ...

# %%
#Transformar o tipo de dados de object para int
df_morte_maternas[['ANO','Morte materna obstétrica indireta','Morte materna obstétrica não especificada','Branca','Preta','Amarela','Parda','Indígena','Cor/Raça Ignorado','Solteiro','Casado','Viúvo','Separado judicialmente','Outro','Estado Civil Ignorado','10 a 14 anos','15 a 19 anos','20 a 29 anos','30 a 39 anos','40 a 49 anos','50 a 59 anos','Durante a gravidez, parto ou aborto','Durante o puerpério, até 42 dias','Durante o puerpério, de 43 dias a menos de 1 ano','Não na gravidez ou no puerpério','Período informado inconsistente','Não informado ou ignorado']] = df_morte_maternas[['ANO','Morte materna obstétrica indireta','Morte materna obstétrica não especificada','Branca','Preta','Amarela','Parda','Indígena','Cor/Raça Ignorado','Solteiro','Casado','Viúvo','Separado judicialmente','Outro','Estado Civil Ignorado','10 a 14 anos','15 a 19 anos','20 a 29 anos','30 a 39 anos','40 a 49 anos','50 a 59 anos','Durante a gravidez, parto ou aborto','Durante o puerpério, até 42 dias','Durante o puerpério, de 43 dias a menos de 1 ano','Não na gravidez ou no puerpério','Período informado inconsistente','Não informado ou ignorado']].astype(int)
df_morte_maternas
# Out:
#       ANO              Estado  Morte materna obstétrica direta  \
# 0    2011            Rondônia                               13
# 1    2011                Acre                                6
# 2    2011            Amazonas                               31
# 3    2011             Roraima                                4
# 4    2011                Pará                               74
# ..    ...                 ...                              ...
# 292  2021   Rio Grande do Sul                               36
# 293  2021  Mato Grosso do Sul                               18
# 294  2021         Mato Grosso                               22
# 295  2021               Goiás                               39
# 296  2021    Distrito Federal                                8
#
#      Morte materna obstétrica indireta  \
# 0                                    2
# 1                                    0
# 2                                   18
# 3                                    2
# ...

# %%
#Exportar para csv a base final mortes maternas (atualizações)
df_morte_maternas.to_csv('./datasets/bases_finais/base_mortes_maternas')

# %%
#Estatistíca descritiva
#Incluir na análise estatistíca os tipos de dados
include =['object', 'int']
df_morte_maternas.describe(include=include)
# Out:
#                 ANO    Estado  Morte materna obstétrica direta  \
# count    297.000000       297                       297.000000
# unique          NaN        27                              NaN
# top             NaN  Rondônia                              NaN
# freq            NaN        11                              NaN
# mean    2016.000000       NaN                        40.616162
# std        3.167615       NaN                        37.043539
# min     2011.000000       NaN                         2.000000
# 25%     2013.000000       NaN                        15.000000
# 50%     2016.000000       NaN                        27.000000
# 75%     2019.000000       NaN                        55.000000
# max     2021.000000       NaN                       213.000000
#
#         Morte materna obstétrica indireta  \
# count                          297.000000
# unique                                NaN
# top                                   NaN
# ...

# %% [markdown]
# ## Perfil de mortalidade materna

# %%
#Verificar o número de mulheres de cada cor/raça
df_cor_raca_f = df_morte_maternas.loc[:,['Branca','Preta','Amarela','Parda','Indígena','Cor/Raça Ignorado']].sum()
df_cor_raca_f
# Out:
# Branca                6377
# Preta                 2197
# Amarela                 50
# Parda                10418
# Indígena               307
# Cor/Raça Ignorado      624
# dtype: int64

# %%
#Verificar o número de mulheres de cada faixa-etária
df_faixa_etaria_f = df_morte_maternas.loc[:,['10 a 14 anos','15 a 19 anos','20 a 29 anos','30 a 39 anos','40 a 49 anos','50 a 59 anos']].sum()
df_faixa_etaria_f
# Out:
# 10 a 14 anos     157
# 15 a 19 anos    2249
# 20 a 29 anos    7667
# 30 a 39 anos    8249
# 40 a 49 anos    1633
# 50 a 59 anos      16
# dtype: int64

# %%
#Verificar o número de mulheres por estado civil
df_estado_civil_f = df_morte_maternas.loc[:,['Solteiro','Casado','Viúvo','Separado judicialmente','Outro','Estado Civil Ignorado']].sum()
df_estado_civil_f
# Out:
# Solteiro                  9421
# Casado                    5683
# Viúvo                      125
# Separado judicialmente     368
# Outro                     2825
# Estado Civil Ignorado     1551
# dtype: int64

# %%
#Verificar o número de mulheres pelo periódo de falecimento
df_falecimento_f = df_morte_maternas.loc[:,['Durante a gravidez, parto ou aborto','Durante o puerpério, até 42 dias','Durante o puerpério, de 43 dias a menos de 1 ano','Não na gravidez ou no puerpério','Período informado inconsistente','Não informado ou ignorado']].sum()
df_falecimento_f
# Out:
# Durante a gravidez, parto ou aborto                  5809
# Durante o puerpério, até 42 dias                    11607
# Durante o puerpério, de 43 dias a menos de 1 ano      835
# Não na gravidez ou no puerpério                       336
# Período informado inconsistente                        46
# Não informado ou ignorado                            1340
# dtype: int64

# %% [markdown]
# ### Análise do dataset Óbito Mensal 2011-2021

# %%
#Checando se a base final de óbito mensal está boa
df_obito_mensal_2011_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ANO        297 non-null    int64
#  1   Estado     297 non-null    object
#  2   Janeiro    297 non-null    object
#  3   Fevereiro  297 non-null    object
#  4   Março      297 non-null    object
#  5   Abril      297 non-null    object
#  6   Maio       297 non-null    object
#  7   Junho      297 non-null    object
#  8   Julho      297 non-null    object
#  9   Agosto     297 non-null    object
#  10  Setembro   297 non-null    object
#  11  Outubro    297 non-null    object
#  12  Novembro   297 non-null    object
#  13  Dezembro   297 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 32.6+ KB

# %%
#Renomear nome dados das colunas 
df_obito_mensal_2011_2021 = df_obito_mensal_2011_2021.replace(['-'],[0])
df_obito_mensal_2011_2021
# Out:
#       ANO              Estado Janeiro Fevereiro Março Abril Maio Junho Julho  \
# 0    2011            Rondônia       0         1     1     2    0     3     1
# 1    2011                Acre       1         2     0     0    2     0     0
# 2    2011            Amazonas       5         5     5     6    3     6     4
# 3    2011             Roraima       0         1     0     1    1     0     0
# 4    2011                Pará       7         5     5     5    7    10    12
# ..    ...                 ...     ...       ...   ...   ...  ...   ...   ...
# 292  2021   Rio Grande do Sul       6         2    20    17   12    14    10
# 293  2021  Mato Grosso do Sul       5         4    12     6    6     6     5
# 294  2021         Mato Grosso       7         2     9    20    7    18     6
# 295  2021               Goiás       5         9    25    24   15     9    14
# 296  2021    Distrito Federal       1         1     3     9    6     4     4
#
# ...

# %%
#Transformar o tipo de dados de object para int
df_obito_mensal_2011_2021[['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']] = df_obito_mensal_2011_2021[['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']].astype(int)
df_obito_mensal_2011_2021
# Out:
#       ANO              Estado  Janeiro  Fevereiro  Março  Abril  Maio  Junho  \
# 0    2011            Rondônia        0          1      1      2     0      3
# 1    2011                Acre        1          2      0      0     2      0
# 2    2011            Amazonas        5          5      5      6     3      6
# 3    2011             Roraima        0          1      0      1     1      0
# 4    2011                Pará        7          5      5      5     7     10
# ..    ...                 ...      ...        ...    ...    ...   ...    ...
# 292  2021   Rio Grande do Sul        6          2     20     17    12     14
# 293  2021  Mato Grosso do Sul        5          4     12      6     6      6
# 294  2021         Mato Grosso        7          2      9     20     7     18
# 295  2021               Goiás        5          9     25     24    15      9
# 296  2021    Distrito Federal        1          1      3      9     6      4
#
# ...

# %%
#Checando novamente se a base final de óbito mensal está boa
df_obito_mensal_2011_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ANO        297 non-null    int64
#  1   Estado     297 non-null    object
#  2   Janeiro    297 non-null    int32
#  3   Fevereiro  297 non-null    int32
#  4   Março      297 non-null    int32
#  5   Abril      297 non-null    int32
#  6   Maio       297 non-null    int32
#  7   Junho      297 non-null    int32
#  8   Julho      297 non-null    int32
#  9   Agosto     297 non-null    int32
#  10  Setembro   297 non-null    int32
#  11  Outubro    297 non-null    int32
#  12  Novembro   297 non-null    int32
#  13  Dezembro   297 non-null    int32
# dtypes: int32(12), int64(1), object(1)
# memory usage: 18.7+ KB

# %%
#Estatistíca descritiva
df_obito_mensal_2011_2021.describe().T
# Out:
#            count         mean       std     min     25%     50%     75%  \
# ANO        297.0  2016.000000  3.167615  2011.0  2013.0  2016.0  2019.0
# Janeiro    297.0     5.656566  6.098009     0.0     2.0     4.0     8.0
# Fevereiro  297.0     5.148148  5.470894     0.0     2.0     3.0     7.0
# Março      297.0     6.569024  7.955288     0.0     2.0     4.0     9.0
# Abril      297.0     6.777778  8.672988     0.0     2.0     4.0     9.0
# Maio       297.0     7.175084  7.844540     0.0     2.0     4.0    10.0
# Junho      297.0     6.319865  7.320974     0.0     2.0     4.0     8.0
# Julho      297.0     5.707071  6.414594     0.0     1.0     4.0     7.0
# Agosto     297.0     4.969697  4.977900     0.0     1.0     3.0     7.0
# Setembro   297.0     4.710438  5.164555     0.0     1.0     3.0     6.0
# Outubro    297.0     4.632997  4.854295     0.0     1.0     3.0     6.0
# Novembro   297.0     4.663300  4.894264     0.0     1.0     3.0     6.0
# ...

# %%
#Exportar para csv a base final (atualização)
df_obito_mensal_2011_2021.to_csv('./datasets/bases_finais/base_obito_mensal_2011_2021')

# %% [markdown]
# ## Ano e mês que ocorreram mais falecimentos maternos

# %%
#Verificar ano e mês que ocorreram mais falecimentos
df_ano_falecimento_f = df_obito_mensal_2011_2021[['ANO','Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']].groupby('ANO').sum()
df_ano_falecimento_f.insert(loc=0, column='ANO', value=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])

# %%
#Verificando informações gerais da base mortes maternas
df_ano_falecimento_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 2011 to 2021
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ANO        11 non-null     int64
#  1   Janeiro    11 non-null     int32
#  2   Fevereiro  11 non-null     int32
#  3   Março      11 non-null     int32
#  4   Abril      11 non-null     int32
#  5   Maio       11 non-null     int32
#  6   Junho      11 non-null     int32
#  7   Julho      11 non-null     int32
#  8   Agosto     11 non-null     int32
#  9   Setembro   11 non-null     int32
#  10  Outubro    11 non-null     int32
#  11  Novembro   11 non-null     int32
#  12  Dezembro   11 non-null     int32
# dtypes: int32(12), int64(1)
# memory usage: 704.0 bytes

# %%
df_ano_falecimento_f
# Out:
#        ANO  Janeiro  Fevereiro  Março  Abril  Maio  Junho  Julho  Agosto  \
# ANO
# 2011  2011      141        131    147    133   168    122    142     142
# 2012  2012      138        138    142    144   161    130    137     115
# 2013  2013      166        126    158    152   184    152    128     123
# 2014  2014      160        137    163    149   178    153    166     112
# 2015  2015      162        142    156    163   158    144    128     131
# 2016  2016      148        154    169    178   165    142    128     126
# 2017  2017      141        127    184    155   144    162    151     142
# 2018  2018      137        126    140    145   174    136    135     141
# 2019  2019      152        135    148    142   152    141    121     116
# 2020  2020      139        115    149    176   252    208    201     154
# 2021  2021      196        198    395    476   395    387    258     174
#
#       Setembro  Outubro  Novembro  Dezembro
# ANO
# ...

# %% [markdown]
# ### Ano que houve mais falecimentos

# %%
#Verificar no ano que houve mais falecimentos
df_ano_falecimento_max = df_ano_falecimento_f.max()
df_ano_falecimento_max
# Out:
# ANO          2021
# Janeiro       196
# Fevereiro     198
# Março         395
# Abril         476
# Maio          395
# Junho         387
# Julho         258
# Agosto        174
# Setembro      147
# Outubro       149
# Novembro      142
# Dezembro      154
# dtype: int64

# %% [markdown]
# ### De acordo com o periódo que houvem mais falecimentos, quais foram os principais estados das ocorrências?

# %%
#Filtragem de todas as ocorrências de 2021
df_ano_falecimento_2021_max = df_obito_mensal_2011_2021[(df_obito_mensal_2011_2021.ANO == 2021) & (df_obito_mensal_2011_2021.Estado)]
#Atualizando o index
df_ano_falecimento_2021_max = df_ano_falecimento_2021_max.reset_index(drop=True)
#Soma de ocorrências por estadp
df_ano_falecimento_2021 = df_ano_falecimento_2021_max.eval('Óbitos = Janeiro + Fevereiro + Março + Abril + Maio + Junho + Julho + Agosto + Setembro + Outubro + Novembro + Dezembro')
#Filtragem das colunas úteis
df_ano_falecimento_2021 = df_ano_falecimento_2021.loc[:,['Estado', 'Óbitos']]
df_ano_falecimento_2021
# Out:
#                  Estado  Óbitos
# 0              Rondônia      42
# 1                  Acre      15
# 2              Amazonas     122
# 3               Roraima      36
# 4                  Pará     166
# 5                 Amapá      14
# 6             Tocantins      43
# 7              Maranhão     146
# 8                 Piauí      59
# 9                 Ceará     129
# 10  Rio Grande do Norte      65
# 11              Paraíba      71
# 12           Pernambuco      93
# 13              Alagoas      54
# 14              Sergipe      26
# 15                Bahia     195
# 16         Minas Gerais     229
# 17       Espírito Santo      49
# 18       Rio de Janeiro     320
# 19            São Paulo     457
# 20               Paraná     187
# 21       Santa Catarina      85
# 22    Rio Grande do Sul     113
# 23   Mato Grosso do Sul      54
# 24          Mato Grosso      84
# 25                Goiás     140
# 26     Distrito Federal      36

# %%
#Estados com maiores ocorrências de óbitos
df_ano_falecimento_2021_top5_max = df_ano_falecimento_2021.nlargest(5,'Óbitos')
#Atualizando o index
df_ano_falecimento_2021_top5_max = df_ano_falecimento_2021_top5_max.reset_index(drop=True)
df_ano_falecimento_2021_top5_max
# Out:
#            Estado  Óbitos
# 0       São Paulo     457
# 1  Rio de Janeiro     320
# 2    Minas Gerais     229
# 3           Bahia     195
# 4          Paraná     187

# %%
#Estados com menores ocorrências de óbitos
df_ano_falecimento_2021_top5_min = df_ano_falecimento_2021.nsmallest(5,'Óbitos')
#Atualizando o index
df_ano_falecimento_2021_top5_min = df_ano_falecimento_2021_top5_min.reset_index(drop=True)
df_ano_falecimento_2021_top5_min
# Out:
#              Estado  Óbitos
# 0             Amapá      14
# 1              Acre      15
# 2           Sergipe      26
# 3           Roraima      36
# 4  Distrito Federal      36

# %% [markdown]
# # Visualização dos dados

# %%
# Importando os pacotes
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_cor_raca_f.plot(kind=('bar'))
plt.xlabel('Cor/Raça')
plt.ylabel('Número de Ocorrências')
plt.title('Óbitos por Cor/Raça')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_faixa_etaria_f.plot(kind=('bar'))
plt.xlabel('Faixa-Etária')
plt.ylabel('Número de Ocorrências')
plt.title('Óbitos por Faixa-Etária')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_estado_civil_f.plot(kind=('barh'))
plt.xlabel('Número de Ocorrências')
plt.ylabel('Estado Civil')
plt.title('Óbitos por Estado Civil')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_falecimento_f.plot(kind=('barh'))
plt.xlabel('Número de Ocorrências')
plt.ylabel('Momento')
plt.title('Óbitos Graves ou no Puerpério')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_ano_falecimento_2021_top5_max.plot(kind=('bar'))
plt.xlabel('Faixa-Etária')
plt.ylabel('Número de Ocorrências')
plt.title('Óbitos por Faixa-Etária')
plt.legend()
plt.show()

# %%
df_ano_falecimento_2021_top5_min.plot(kind=('bar'))
plt.xlabel('Faixa-Etária')
plt.ylabel('Número de Ocorrências')
plt.title('Óbitos por Faixa-Etária')
plt.legend()
plt.show()
